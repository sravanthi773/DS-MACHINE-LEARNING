# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/DS-MACHINE-LEARNING/blob/main/Ds_ml_R_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

d={
    "area":[1,2,3,4],
    "rice_yield":[10,20,30,40]
}

df=pd.DataFrame(d)

X=df.area.values
Y=df.rice_yield.values

plt.xlabel(X)
plt.ylabel(Y)

plt.scatter(X,Y)
plt.show()

# %%
import pandas as pd
from scipy import stats

d={
    "area":[1,2,3,4],
    "rice_yield":[10,20,30,40]
}

df=pd.DataFrame(d)

X=df.area.values
Y=df.rice_yield.values

slope,intercept,r_value,p_value,std_err=stats.linregress(X,Y)

print(r_value)
# Out:
# 1.0

# %%
import pandas as pd
from scipy import stats

d={
    "a":[600,3000,2,3400,4],
    "b":[550000,565000,610000,680000,725000]
}

df=pd.DataFrame(d)

X=df.a.values
Y=df.b.values

slope,intercept,r_value,p_value,std_err=stats.linregress(X,Y)

print(r_value)
# Out:
# -0.08936334177039705

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

d={
    "area":[1,6,3,5],
    "rice_yield":[10,20,30,40]
}

df=pd.DataFrame(d)

X=df.area.values
Y=df.rice_yield.values

plt.xlabel(X)
plt.ylabel(Y)

plt.scatter(X,Y)
plt.show()

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

d={
    "area":[1,2,3,4],
    "rice_yield":[15,20,50,40]
}

df=pd.DataFrame(d)

X=df.area.values
Y=df.rice_yield.values

plt.xlabel(X)
plt.ylabel(Y)

plt.scatter(X,Y)
plt.show()
