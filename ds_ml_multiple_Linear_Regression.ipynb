# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/DS-MACHINE-LEARNING/blob/main/ds_ml_multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-41d14f36-83e7-4351-acb6-ae68b9c75939" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41d14f36-83e7-4351-acb6-ae68b9c75939">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices1.csv")
print(df)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices1.csv")

print("mean of the bedrooms")
print(df.bedrooms.mean())
# Out:
# mean of the bedrooms
# 4.2

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices1.csv")

print("Mean of the bedrooms")
print(df.bedrooms.median())
# Out:
# Mean of the bedrooms
# 4.0

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices1.csv")

print("filling missing values with mean\n")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)
print(df)
# Out:
# filling missing values with mean
#
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/homeprices1.csv")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)

a=df.drop('price',axis='columns')

reg=LinearRegression()
reg.fit(a.values,df.price)
print('model trained')
# Out:
# model trained

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/homeprices1.csv")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)

a=df.drop('price',axis='columns')

reg=LinearRegression()
reg.fit(a.values,df.price)

print("intercept is")
print(reg.intercept_)
# Out:
# intercept is
# 221323.00186540396

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/homeprices1.csv")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)

a=df.drop('price',axis='columns')

reg=LinearRegression()
reg.fit(a.values,df.price)

print("coefficients are")
print(reg.coef_)
# Out:
# coefficients are
# [  112.06244194 23388.88007794 -3231.71790863]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/homeprices1.csv")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)

a=df.drop('price',axis='columns')

reg=LinearRegression()
reg.fit(a.values,df.price)

print("price of home 3000 sqrft ,3 bedrooms,40 years old")

print(reg.predict([[3000,3,40]]))
# Out:
# price of home 3000 sqrft ,3 bedrooms,40 years old
# [498408.25158031]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/homeprices1.csv")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)

a=df.drop('price',axis='columns')

reg=LinearRegression()
reg.fit(a.values,df.price)

print("price of home 4000 sqrft ,4 bedrooms,20 years old")

print(reg.predict([[4000,4,20]]))
# Out:
# price of home 4000 sqrft ,4 bedrooms,20 years old
# [698493.93177304]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("/content/homeprices1.csv")

m=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(m)

a=df.drop('price',axis='columns')

reg=LinearRegression()
reg.fit(a.values,df.price)

print("price of home 3000 sqrft ,3 bedrooms,40 years old")

b=112.336758*3000+233.4555678*3+332.5654443*40+233.545454566
print(b)
# Out:
# price of home 3000 sqrft ,3 bedrooms,40 years old
# 351246.80392996606
