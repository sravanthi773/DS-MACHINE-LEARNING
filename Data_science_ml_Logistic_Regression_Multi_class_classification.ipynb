# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/DS-MACHINE-LEARNING/blob/main/Data_science_ml_Logistic_Regression_Multi_class_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn. datasets import load_digits
digits=load_digits()
print(len(digits.data))
# Out:
# 1797

# %%
from sklearn.datasets import load_digits
digits=load_digits()
print(dir(digits))
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
from sklearn.datasets import load_digits
digits=load_digits()
print(digits.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
from sklearn.datasets import load_digits
digits=load_digits()
print(digits.data[0])
# Out:
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]

# %%
from sklearn.datasets import load_digits
digits=load_digits()
print(digits.data[1])
# Out:
# [ 0.  0.  0. 12. 13.  5.  0.  0.  0.  0.  0. 11. 16.  9.  0.  0.  0.  0.
#   3. 15. 16.  6.  0.  0.  0.  7. 15. 16. 16.  2.  0.  0.  0.  0.  1. 16.
#  16.  3.  0.  0.  0.  0.  1. 16. 16.  6.  0.  0.  0.  0.  1. 16. 16.  6.
#   0.  0.  0.  0.  0. 11. 16. 10.  0.  0.]

# %%
from sklearn.datasets import load_digits
digits=load_digits()
print(digits.images)
# Out:
# [[[ 0.  0.  5. ...  1.  0.  0.]
#   [ 0.  0. 13. ... 15.  5.  0.]
#   [ 0.  3. 15. ... 11.  8.  0.]
#   ...
#   [ 0.  4. 11. ... 12.  7.  0.]
#   [ 0.  2. 14. ... 12.  0.  0.]
#   [ 0.  0.  6. ...  0.  0.  0.]]
#
#  [[ 0.  0.  0. ...  5.  0.  0.]
#   [ 0.  0.  0. ...  9.  0.  0.]
#   [ 0.  0.  3. ...  6.  0.  0.]
#   ...
#   [ 0.  0.  1. ...  6.  0.  0.]
#   [ 0.  0.  1. ...  6.  0.  0.]
#   [ 0.  0.  0. ... 10.  0.  0.]]
#
#  [[ 0.  0.  0. ... 12.  0.  0.]
#   [ 0.  0.  3. ... 14.  0.  0.]
#   [ 0.  0.  8. ... 16.  0.  0.]
#   ...
#   [ 0.  9. 16. ...  0.  0.  0.]
#   [ 0.  3. 13. ... 11.  5.  0.]
#   [ 0.  0.  0. ... 16.  9.  0.]]
#
#  ...
#
#  [[ 0.  0.  1. ...  1.  0.  0.]
#   [ 0.  0. 13. ...  2.  1.  0.]
#   [ 0.  0. 16. ... 16.  5.  0.]
#   ...
#   [ 0.  0. 16. ... 15.  0.  0.]
#   [ 0.  0. 15. ... 16.  0.  0.]
#   [ 0.  0.  2. ...  6.  0.  0.]]
#
#  [[ 0.  0.  2. ...  0.  0.  0.]
#   [ 0.  0. 14. ... 15.  1.  0.]
#   [ 0.  4. 16. ... 16.  7.  0.]
#   ...
#   [ 0.  0.  0. ... 16.  2.  0.]
#   [ 0.  0.  4. ... 16.  2.  0.]
#   [ 0.  0.  5. ... 12.  0.  0.]]
#
#  [[ 0.  0. 10. ...  1.  0.  0.]
#   [ 0.  2. 16. ...  1.  0.  0.]
#   [ 0.  0. 15. ... 15.  0.  0.]
#   ...
#   [ 0.  4. 16. ... 16.  6.  0.]
#   [ 0.  8. 16. ... 16.  8.  0.]
#   [ 0.  1.  8. ... 12.  1.  0.]]]

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

digits=load_digits()

plt.matshow(digits.images[0])
plt.gray()
plt.show()

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

digits=load_digits()

plt.matshow(digits.images[1])
plt.gray()
plt.show()

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

digits=load_digits()
plt.gray()

for i in range(5):
    plt.matshow(digits.images[i])
    plt.show()

# %%
from sklearn.datasets  import load_digits

digits=load_digits()

print(digits.target)
# Out:
# [0 1 2 ... 8 9 8]

# %%
from sklearn.datasets  import load_digits

digits=load_digits()

print(digits.target[0:5])
# Out:
# [0 1 2 3 4]

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print('splitting the dataset')
# Out:
# splitting the dataset

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print("model creation")
model=LogisticRegression(solver='lbfgs',max_iter=3000)
model.fit(x_train,y_train)
# Out:
# model creation
# LogisticRegression(max_iter=3000)

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print("model creation")
model=LogisticRegression(solver='lbfgs',max_iter=3000)
model.fit(x_train,y_train)
print(model.score(x_test,y_test))
# Out:
# model creation
# 0.9583333333333334

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print("model creation")
model=LogisticRegression(solver='lbfgs',max_iter=3000)
model.fit(x_train,y_train)
print(model.predict([digits.data[6]]))
# Out:
# model creation
# [6]

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print("model creation")
model=LogisticRegression(solver='lbfgs',max_iter=3000)
model.fit(x_train,y_train)
print(model.predict([digits.data[9]]))
# Out:
# model creation
# [9]

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print("model creation")
model=LogisticRegression(solver='lbfgs',max_iter=3000)
model.fit(x_train,y_train)
print(model.predict([digits.data[20]]))
# Out:
# model creation
# [0]

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection  import train_test_split

digits=load_digits()

x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

print("model creation")
model=LogisticRegression(solver='lbfgs',max_iter=3000)
model.fit(x_train,y_train)
print(model.predict(digits.data[0:5]))
# Out:
# model creation
# [0 1 2 3 4]
