# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanthi773/DS-MACHINE-LEARNING/blob/main/ds_ml_Dummy_Variable%26OneHotEncoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-70e9f974-f641-4c33-99b4-c2ddb19718c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70e9f974-f641-4c33-99b4-c2ddb19718c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices2.csv")
print(df)
# Out:
#           town  area   price
# 0   Vijayawada  2600  550000
# 1   Vijayawada  3000  565000
# 2   Vijayawada  3200  610000
# 3   Vijayawada  3600  680000
# 4   Vijayawada  4000  725000
# 5       Guntur  2600  585000
# 6       Guntur  2800  615000
# 7       Guntur  3300  650000
# 8       Guntur  3600  710000
# 9     Gudiwada  2600  575000
# 10    Gudiwada  2900  600000
# 11    Gudiwada  3100  620000
# 12    Gudiwada  3600  695000

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
print(dummies)
# Out:
#     Gudiwada  Guntur  Vijayawada
# 0          0       0           1
# 1          0       0           1
# 2          0       0           1
# 3          0       0           1
# 4          0       0           1
# 5          0       1           0
# 6          0       1           0
# 7          0       1           0
# 8          0       1           0
# 9          1       0           0
# 10         1       0           0
# 11         1       0           0
# 12         1       0           0

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
print(merged)
# Out:
#           town  area   price  Gudiwada  Guntur  Vijayawada
# 0   Vijayawada  2600  550000         0       0           1
# 1   Vijayawada  3000  565000         0       0           1
# 2   Vijayawada  3200  610000         0       0           1
# 3   Vijayawada  3600  680000         0       0           1
# 4   Vijayawada  4000  725000         0       0           1
# 5       Guntur  2600  585000         0       1           0
# 6       Guntur  2800  615000         0       1           0
# 7       Guntur  3300  650000         0       1           0
# 8       Guntur  3600  710000         0       1           0
# 9     Gudiwada  2600  575000         1       0           0
# 10    Gudiwada  2900  600000         1       0           0
# 11    Gudiwada  3100  620000         1       0           0
# 12    Gudiwada  3600  695000         1       0           0

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')
print(final)
# Out:
#     area   price  Gudiwada  Guntur  Vijayawada
# 0   2600  550000         0       0           1
# 1   3000  565000         0       0           1
# 2   3200  610000         0       0           1
# 3   3600  680000         0       0           1
# 4   4000  725000         0       0           1
# 5   2600  585000         0       1           0
# 6   2800  615000         0       1           0
# 7   3300  650000         0       1           0
# 8   3600  710000         0       1           0
# 9   2600  575000         1       0           0
# 10  2900  600000         1       0           0
# 11  3100  620000         1       0           0
# 12  3600  695000         1       0           0

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['Guntur'],axis='columns')
print(final)
# Out:
#           town  area   price  Gudiwada  Vijayawada
# 0   Vijayawada  2600  550000         0           1
# 1   Vijayawada  3000  565000         0           1
# 2   Vijayawada  3200  610000         0           1
# 3   Vijayawada  3600  680000         0           1
# 4   Vijayawada  4000  725000         0           1
# 5       Guntur  2600  585000         0           0
# 6       Guntur  2800  615000         0           0
# 7       Guntur  3300  650000         0           0
# 8       Guntur  3600  710000         0           0
# 9     Gudiwada  2600  575000         1           0
# 10    Gudiwada  2900  600000         1           0
# 11    Gudiwada  3100  620000         1           0
# 12    Gudiwada  3600  695000         1           0

# %%
import pandas as pd
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

print(x)
print(y)
# Out:
#     area  Gudiwada  Guntur  Vijayawada
# 0   2600         0       0           1
# 1   3000         0       0           1
# 2   3200         0       0           1
# 3   3600         0       0           1
# 4   4000         0       0           1
# 5   2600         0       1           0
# 6   2800         0       1           0
# 7   3300         0       1           0
# 8   3600         0       1           0
# 9   2600         1       0           0
# 10  2900         1       0           0
# 11  3100         1       0           0
# 12  3600         1       0           0
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

model=LinearRegression()
model.fit(x,y)
print('model got trained')
# Out:
# model got trained

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

model=LinearRegression()
model.fit(x,y)
print(model.predict(x))
# Out:
# [539709.73984091 590468.71640508 615848.20468716 666607.18125133
#  717366.1578155  579723.71533005 605103.20361214 668551.92431735
#  706621.15674047 565396.15136531 603465.38378844 628844.87207052
#  692293.59277573]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

model=LinearRegression()
model.fit(x,y)
print(model.score(x,y))
# Out:
# 0.9573929037221874

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

model=LinearRegression()
model.fit(x,y)
print(model.predict([[2600,0,0,1]]))
# Out:
# [539709.73984091]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')


df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

model=LinearRegression()
model.fit(x,y)
print(model.predict([[3400,0,1,0]]))
# Out:
# [681241.66845839]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("/content/homeprices2.csv")
dummies=pd.get_dummies(df.town,dtype=int)
merged=pd.concat([df,dummies],axis='columns')
final=merged.drop(['town'],axis='columns')

x=final.drop('price',axis='columns')
y=final.price

model=LinearRegression()
model.fit(x,y)
print(model.predict([[3400,1,0,0]]))
# Out:
# [666914.10449365]
